# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import requests
import datetime
import time

#Current bug: can't post a confession that includes hash sign #

fbPageid = '100659372403370'
fbToken = 'EAAFl64vH3kABO3b3slihLZC1CxKeecPYJaztK7vppslem5y3RZA8XxOrTaLL3bhq4mIda31eRfE2PZCxxCZBRbPsiCnGMZAZANjGtWer3dhhNTxYaz3r1O8baacy5DiCd2SpZAVmdLZAuyB4KAQJ9PBH1Aa3mgFdjpHrUyoQZCCBkkROIDYZCutlMl1otx6JyJcXRer7v8yP49HkpHcq49b9G30raU7k0vYZBL0atcq95EZD'

def postOnFacebook(confession):
    response = requests.post("https://graph.facebook.com/" + fbPageid + "/feed" +
                            "?published=true" +
                            "&message=" + confession +
                            "&access_token=" + fbToken)
    return response

# %%
confession="%231000\nmale"


response = requests.post("https://graph.facebook.com/" + fbPageid + "/feed" +
                            "?published=true" +
                            "&message=" + confession +
                            "&access_token=" + fbToken)

# %%
response.json()
# Out:
# {'error': {'message': 'Error validating access token: Session has expired on Saturday, 13-Apr-24 14:00:00 PDT. The current time is Saturday, 13-Apr-24 16:41:40 PDT.',
#   'type': 'OAuthException',
#   'code': 190,
#   'error_subcode': 463,
#   'fbtrace_id': 'AOHPzvW_KtJE7VM3swOOQj1'}}

# %%
postOnFacebook(" 100\nmale, graduate:\nhello ")
# Out:
# <Response [403]>

# %% [markdown]
# ### Get posts

# %%
import requests

access_token = "EAAFl64vH3kABO3b3slihLZC1CxKeecPYJaztK7vppslem5y3RZA8XxOrTaLL3bhq4mIda31eRfE2PZCxxCZBRbPsiCnGMZAZANjGtWer3dhhNTxYaz3r1O8baacy5DiCd2SpZAVmdLZAuyB4KAQJ9PBH1Aa3mgFdjpHrUyoQZCCBkkROIDYZCutlMl1otx6JyJcXRer7v8yP49HkpHcq49b9G30raU7k0vYZBL0atcq95EZD"
page_id = "100659372403370"
since_date = "2023-04-13"  # Start date
until_date = "2024-01-01"  # End date

# Initialize an empty list to store posts
all_posts = []

# Facebook Graph API endpoint URL with date parameters
url = f"https://graph.facebook.com/v19.0/{page_id}/posts?access_token={access_token}&since={since_date}&until={until_date}&limit=100"

while True:
    response = requests.get(url)
    data = response.json()
    
    # Check if there are more posts
    if 'data' in data:
        all_posts.extend(data['data'])
    
    # Check if there are more pages of posts
    if 'paging' in data and 'next' in data['paging']:
        url = data['paging']['next']
    else:
        break

# Print the post details
for post in all_posts:
    print(f"Post ID: {post['id']}")
    print(f"Message: {post.get('message', 'N/A')}")
    print("----------")
# Out:
# Post ID: 100659372403370_350757634317215
# Message: 4775
# Male, Junior:
# bmonasbet video el elections, just wanted to say that the bylaws used to say that the union is "an independent free union that is not governed or controlled by Nile University’s Administration, Staff, Faculty or Board of Trustees." Meanwhile it's the student life office who interviewed & chosen those people. nice joke
# ----------
# Post ID: 100659372403370_344930954899883
# Message: 4774
# Male, Junior, Biotechnology:
# بعد اسبوع الميدترم عاوزين نشكر دكتور ال Virology وودكتتور ال genetic engineering عشان هما بجد سوويين نفسين ودي حاجه قليله جدا الفتره دي..
# +اننهم بينقلوولنا خبرتهم ويفيدونا جدا بجد ومبيبخلوش علينا بمعلومه.
# Thank you♥️♥️
# ----------
# Post ID: 100659372403370_344930724899906
# Message: 4773
# Prefer not to say:
# ايه حلولكم للشعور بالوحدة في الجامعة؟
# ----------
# Post ID: 100659372403370_344930258233286
# Message: 4772
# Female, Sophomore, Engineering:
# حسبي الله ف دي جاااامعة اعصاااااااااااااابي وصحتي  بتموت
# ----------
# Post ID: 100659372403370_344929904899988
# Message: 4771
# Male, Junior, Computer Science:
# يا مريم هنتكلم تاني ولا الوقت فات و احلامي راحت من سكات.
# ----------
# Post ID: 100659372403370_343414695051509
# Message: 4770
# Male:
# WHY TF YOU KEEP SHOWING UP IN MY DREAMS???
# ----------
# Post ID: 100659372403370_343414525051526
# Message: 4769
# Female, Senior, Biotechnology:
# كنت واحشني يا أدمن هلا بالعودة ❤️
# ----------
# Post ID: 100659372403370_343414248384887
# Message: 4768
# Male, Senior, Computer Science:
# احب اوجه رساله للي بيدو مادة Theory of Computing السمستر ده
# اتقوا الله شويه في الدرجات و موضوع Plagiarism مش اي غلطه بسيطه في اسيمنت او امتحان او حتى تاسك تنقصوا عليها بالشكل ده
# مبقاش بحضر لابات و محاضرات ومنتظم وانقص في تاسكات وواحد مبيحضرش مينقصش ويمشوه
# ده مش حقد والله عليهم بس الموضوع بيتكرر كتير و الواحد زهق انا اول مره اشتكي من ماده بالطريقة دي
# افتكروا ان الي بيوسع على الناس ربنا بيوسع عليه
# ----------
# Post ID: 100659372403370_343413825051596
# Message: 4767
# Male, Senior, Finance:
# this girl who wears very sweet dresses may be she in business. I want to tell her that you are prettier than the moon.
# ----------
# Post ID: 100659372403370_342823551777290
# Message: 4767
# Male:
# Shbab yaret lw had 3ndo hal l el burning out y2olo 3shan el mwdo3 kharag 3n l sytra w mb2tsh ader A3ml ay haga
# ----------
# Post ID: 100659372403370_342692341790411
# Message: 4766
# Female, Junior, AI:
# AWZA ASAFR 😡
# ----------
# Post ID: 100659372403370_342691725123806
# Message: 4765
# Male, Senior, Computer Science:
# يا شباب لو هبيع هودي. في الجامعه الديزاين زي ما انت عايز و خامات كويسه ايه رأيكو ؟
# ----------
# Post ID: 100659372403370_342690971790548
# Message: 4764
# Male, Senior:
# Ever since I knew the world we live in I've been raised on the fact that Zionists are the worst people there can ever be and that the occupation is nothing but a finite force that robbed the Palestinians of their land and rights, and they never failed to verify those facts each time I looked at the news or even surfed the internet. We all know that Al-Quds has been occupied multiple times with similar situations to the current one, but we also know how resilient Palestinians are, and how each time this happens, the Occupation gets kicked out more powerfully than the last time.
#
# I don't have a background in politics, but I know that even though war is essentially bad, sometimes it is the only solution.
#
# We, Arabs, Muslims, and every single educated person are at war right now, whether we are actively fighting or not.
#
# Palestine is free it will always be free, the people of Palestine are the most resilient people on earth right now, and no matter how long it takes, we will hear it all over the news one day...
#
# #I_Stand_With_Palestine 🇵🇸
# #إتكلمو_عن_فلسطين 🇵🇸
#
# Note: I will be leaving some sources where you can donate to the right places down below 👇
#
# Red Crescent:
# https://www.egyptianrc.org/Donate
#
# Islamic Relief:
# https://www.islamicreliefcanada.org/emergencies/palestine-appeal
#
# MAP Aid for Palestine:
# https://www.map.org.uk/donate/donation-details/484
#
# Here are some accounts to keep up with the news:
# https://www.instagram.com/motaz_azaiza/
#
# https://www.instagram.com/saleh_aljafarawi/
#
# https://www.instagram.com/fababs/
#
# https://www.instagram.com/itsbandage/
# ----------
# Post ID: 100659372403370_342690531790592
# Message: 4763
# Male, Junior, Computer Science:
# عايزين ديلر كويس قريب من الجامعه و يكون بيعرف يلف الفركه بسيجار
# ----------
# Post ID: 100659372403370_342690045123974
# Message: 4762
# Female, Senior:
# كنت عايزه اقوله انه الوقت اتأخر اوي وحد متقدملي و كان امنيه من امنياتي انه كان يكون انت بس مكنش ينفع ابدأ انا بحاجه مكنش هينفع
# ----------
# Post ID: 100659372403370_342689778457334
# Message: 4761
# Male, Senior:
# عندي مشكلة في ال mentality  بتاعتي في الشغل او في المذاكرة او اي حاجة مهمة اني  بشتغل شوية وبقول كفاية كدا واخد بريكس بقي وبشوف الي عملته دا جامد وفشيخ لحد ما اتفاجئ اني حرفيا شغلي متوسط اوي وكمان في ناس عملت 10 اضعاف الشغل دا في نفس المدة ، انا عايز ادي اكتر بس مهما زودت بزود حبة صغيرين وبقول كدا جامد هل حد عنده حل او طريقة في المذاكرة والشغل تخليني انسي الفكرة دي لانها لازقالي
# ----------
# Post ID: 100659372403370_342689265124052
# Message: 4760
# Male, Graduate, Civil:
# "ايييييييه يا نيل يا جميل
# دفعة 2016 بتسلم عليك
# واحلى إعتماد من السعوديه والامارات
# من مكاني هذا وال6500 ريال مع وجود 3 أطفال
# بقيت اجيب شبسي 160جرام وده بالنسبالي إنجاز
# يا اهليه انتي يا مقوره يا ورق العنب
# اقلبوها خاطبه يا ولاد عشان مفيهاش شغل جايلك من المستقبل
# اللي لسه fresh بقولك اهو اخلع بدل ما تعمل زيي"
# ----------
# Post ID: 100659372403370_339300905462888
# Message: 4759
# Male, Junior, BMD:
# Is this page still alive
# ----------
# Post ID: 100659372403370_272039995522313
# Message: 4758
# Male, Senior, Mechanical:
#
# عاوز حد يقولى الحجات التخلينى اعمل شغل جامد فالبروجكتات انا بحاول على قد مقدر يعنى بس هى شاطرة والليفل بتاعها عالى فشخ ودى الحاجة الوحيده الممكن نتكلم فيها
# لو حد يعرف كورس يلم الهناخده السنه الجاية يباصيهولى يرجالة
# ----------
# Post ID: 100659372403370_272039982188981
# Message: 4757
# Male:
#
# I wanna die I am a failure
# ----------
# Post ID: 100659372403370_272039955522317
# Message: 4756
# Male:
#
# جماعة انا بحس اني قليل اوي و شايف نفسي كدة و دا مدايقني جدا و مش عارف احله ازاي، و دا دايما بيبعد الناس عني عشان انا بعاملهم اكنهم هم كل حاجة و انا ولا حاجة فبيشوفوا نفسهم عليا و ساعتها انا بكره نفسي اكتر، مش عندي ثقة في نفسي شايف نفسي حاجة صغيرة و مقزز جمب الناس التانية فهل دا ليه علاج او ايه الحل
# ----------
# Post ID: 100659372403370_272039792189000
# Message: 4755
# Male:
#
# خلاص يا جدعان، قسما بالله عرفنا ان nutshell رجع خلاص
# ----------
# Post ID: 100659372403370_272039752189004
# Message: 4754
# Male, Freshman, Computer Science:
#
# As a freshman my problem solving skills msh ad kda fa fe 7aga asht8l 3leha fl agaza gher l mwdo3 dh mohema wla kfaya eny asht8l 3l mwdo3 dh bs?
# ----------
# Post ID: 100659372403370_272039708855675
# Message: 4753
# Female:
#
# لسه هدخل سنة تالتة و شايلة هم مشروع التخرج من دلوقتي لأني مليش تيم معين بشتغل معاه و الناس اللي مفروض صحابي كل واحد بيدور علي مصلحته وبيدخلو في تيمز و بيسيبوني اتسوح و الدكاترة بيدخلوني مع اي حد مش لاقي مكان في تيم ف الدفعة و غالباً بيبقو ناس ملهمش ف شغل البروجكتات اصلا فا بتسوح و بشيل الشغل لوحدي.
# انا مش عارفة اتصرف ازاي بصراحة و حاسة ان الوقت اتأخر اني احاول ادخل مع ناس تانية و وفي نفس الوقت خايفة اتقابل بالرفض فا ممكن تنصحوني اعمل ايه انا بجد شايلة هم الموضوع ده من دلوقتي مع العلم اني مش شخص مهمل بالعكس يعني انا بشتغل بس الفكرة كلها اني هادية و يعتبر مليش ظهور.
# اسفة علي الإطالة بس انا فعلاً مش عارفة اعمل ايه.
# ----------
# Post ID: 100659372403370_269140952478884
# Message: 4752
# Male, Senior:
#
# هما بتوع إِمٖ يُوَ إنِ لسه بيدفعو ٦٠٠ جنيه عشان يبقو ديليجيتز ولا وصلت لكم دلوق؟
# ----------
# Post ID: 100659372403370_269140935812219
# Message: 4751
# Male, Biotechnology:
#
# Elbnaat dol elwa7d nfso yfhm byfkro ezayyy bgd bt5lek b3d ma t7bha tkrhk feha wa fe elbnat kolhom
# ----------
# Post ID: 100659372403370_269140912478888
# Message: 4750
# Male:
#
# anybody wanna watch Barbie movie with me? I'm looking for people who aren't homophobic to join in
# ----------
# Post ID: 100659372403370_269140755812237
# Message: 4749
# Female, Junior, Computer Science:
#
# حاسة اني مضايقة من نفسي منزلتش intern خالص قدمت بس محدش كلمني ومش بعمل حاجة ف الاجازة مش قادرة حاسة اني طاقتي خلصت من الترم الفات مش قادرة اتعلم حاجة او اذاكر انا مع نفسي وان انا الوحيدة الفاشلة ال مش بتعمل حاجة
# ----------
# Post ID: 100659372403370_269140722478907
# Message: 4748
# Male:
#
# انا كنت بحب واحده من و انا في اولي ثانوي بس هي قالتلي مش بحبك و خلاص بعدنا و انا زعلت جامد و عملت كل اللي اقدر عليه عشان اعرف انساها و معرفتش روحت الجيم كلت الحديد و مجبش معايا نتيجة سافرت سفريات كتير ولا حاجة نفعت وركزت في دراستي كويس و بجيب درجات عالية الحمدلله وبرضه مش مبسوط و اشتغلت كتير عشان الشغل ينسيني و معرفتش و خرجت كتير و عرفت ناس كتير بس مفيش حد عرف يعوضني عنها حتي مبقتش عارف اتعامل ولا اتكلم مع اي بنت تانية و كل ما واحدة تكلمني او حاجة معرفش اتكلم معاها كويس و بتهته في الكلام و امشي بسرعة و بقعد ادور على اي بنت في الجامعة شبهها عشان اتكلم معاها تفكرني بيها حتي بس مش عارف و انا دلوقتي داخل تالتة و مش عارف اعمل ايه و لا هفضل كده لغاية امتي
# ----------
# Post ID: 100659372403370_269140669145579
# Message: 4747
# Male:
#
# بحبها بس اخوها ظابط
# ----------
# Post ID: 100659372403370_267654522627527
# Message: 4746
# Female, Senior:
#
# انا جالي اكتئاب و نوبات قلق و اضطراب  بسبب ناس في الجامعه . وحقيقي مش مسامحه الناس اللي وصلتني اني احس اني شخص وحش و اني مستحقش حاجه
# وانهم حكموا عليا في ظروف صعبه جدا بجد
# و حسبي الله ونعم الوكيل .
# ----------
# Post ID: 100659372403370_267654492627530
# Message: 4745
# Female, Senior:
#
# حتي في الاجازة مش بتنزل ال confessions بتاعتي!
# استاذ ادمن انت شكلك مش عايز تبدأ صفحة جديدة
# ----------
# Post ID: 100659372403370_267654455960867
# Message: 4744
# Prefer not to say:
#
# اعمل ايه لو فيه حد مُصر أنه يتكلم عليا و يقول كلام محصلش و يشوه سمعتي برغم اني مأذيتهوش ولا عملتله حاجه مع العلم اني قطعت علاقتي بيه بس مع ذلك هو مكمل في اللي هو بيعمله و في نفس الوقت انا مش حابب ااذيه
# ----------
# Post ID: 100659372403370_267654442627535
# Message: 4743
# Male, Senior, Business:
#
# هو الترم الاول  الساعه بردو هتبقا ب 3450 ؟!
# ----------
# Post ID: 100659372403370_267654202627559
# Message: 4742
# Female, Senior, Business:
#
# عندي مشكلة في اني ديما بيتسربلي شعور اني مقدرش اعمل حاجة
# لما اتخرج مش هقدر ابقى في شغل كويس، مقدرش ابقى حد شاطر كفاية، مقدرش ابقى كويسة كفاية عموما
# معرفش ليه ديما بحس بكدة و عندي خوف رهيب من ان الافكار دي تسيطر عليا و توقفني مكاني
# انا الحمدلله مستوايا كويس و بحاول على قد ما اقدر اشتغل على نفسي
# بس الممشكلة اني بحس ان دا مش كفاية
# اهلي مش بيحسسوني كدة خالص بالعكس بيشجعوني و يقدروا مجهودي دا كويس بس المشكلة دي فيا انا ( اكيد ليها سبب بس انا مش شايفاه)
# المشكلة دي بتخليني اتأثر بإنجاز اي حد جنبي و بحس بإني مش كويسة كفاية علشان كدة معرفتش اعمل انجاز زيه
# هي مش فكرة مقارنة بالناس لا خالص، المشكلة في نظرتي لنفسي بعيدا عن الناس
# انا مش حابة اكون الشخص دا و مش حابة اكون الشخص اللي يتأثر بشكل سلبي بنجاح الناس
# حابة لو حد عدى بمشكلة زي دي و عرف يحلها او حتى عنده نصيحة يقولي هبقى شاكرة ليه جدا
# ----------
# Post ID: 100659372403370_267654172627562
# Message: 4741
# Male, Junior, Engineering:
#
# كنت بحب بنت في بايو تكنولوجي وحولت ماست وعملتلي بلوك ومش بتكلمني خالص بس أنا كنت بحبها أعمل ايه أو اوصلها ازاي هي أكيد هتشوف الي كاتبه بحبك يا إس
# ----------
# Post ID: 100659372403370_267654115960901
# Message: 4740
# Male:
#
# رداً على 4716
# "هيجرى ايه يا جماعة لو نعمل blind dates هتبقى جامدة أوي ممكن نعمل booth ناس تسجل اللي interested في الحوار ده و ن match كل اتنين مع بعض و يتكلموا و هما مش شايفين بعض لمدة ٥ دقائق كدا و يقرروا هما هينزلوا مع بعض date حقيقي و لا لأ ممكن ألاقي ناس مقبلة على ده؟"
#
# يلا يا ***** روح انزل الجيم و بطل دلع علشان مفيش رجالة بينزلوا dates مع نسوان، الرجالة بيتجوزوا علطول لما يكونوا جاهزين.
#
# بلاش تتأثر بشخصية الارجوزات اللي بيمشوا يريلوا على النسوان الرخيصة اللي بتشوفهم في فيديوهات الdating اللي بتحاول تنشرلنا ثقافة غربية دي و تخلينا نعتاد عليها.
#
# العيال اللي بيطلعوا في البرامج دي اصلا شوية عيال أرايل متعرفش حاجة عن المروءة و يا أخي ده انت حتى مترضاش ان اختك او حد البنات اللي في عيلتك تعمل حاجة زي دي و تنزل بما يسمى "date" مع واحد.
# ----------
# Post ID: 100659372403370_267654099294236
# Message: 4739
# Prefer not to say:
#
# انا بمشي لابس سماعات دايما عشان الناس متفتكرنيش مجنون وانا بكلم نفسي
# ----------
# Post ID: 100659372403370_265117356214577
# Message: 4738
# Prefer not to say:
#
# To someone here:
# الشخصية الغامضة كشفها صياح threads
# ----------
# Post ID: 100659372403370_265117129547933
# Message: 4737
# Male, Engineering:
#
# هو أنا ممكن اشتغل ايه لو مفيش حاجة لسه بعرف أعملها أوي و نوعا ما مش شاطر في دراستي (ياريت محدش يهاهاه)
# ----------
# Post ID: 100659372403370_265117089547937
# Message: 4736
# Male:
#
# يخربيت الصياح بتاع الدفعات الجديدة جروب  Whatsup in NU  كان من الجروبات الهادية الواحد كان بيدخل عليه يشوف لو في حاجة مهمة دلوفتي كلو اسئلة بلا هدف و نص الاسئلة لو عملو search عليها في الجروب هيلاقوها و النص التاني مش مكانها الجروب اساسا اكبرو يا حبايبي شوية انتو مش في تانية ابتدائي
# ----------
# Post ID: 100659372403370_265116899547956
# Message: 4735
# Female:
#
# موضوع لي النقاش اي رايكم في الرجل الا بيشتم حبيته وشتايم وحشه زي ما يكون في خناقه مع صحابه مثلا وهي تعمل اي
# ----------
# Post ID: 100659372403370_265116852881294
# Message: 4734
# Male, Freshman, Business:
#
# Day 1 of looking for a date to Oppenheimer w Barbie
# ----------
# Post ID: 100659372403370_265116819547964
# Message: 4733
# Female, Junior:
#
# يا م يا اللي في هندسة ميكانيكا بطلي صياح و ندب عليه على الاكونت بتاعك يا حبيبتي هو مرتبط دلوقتي
# ----------
# Post ID: 100659372403370_265116792881300
# Message: 4732
# Female, Sophomore, Business:
#
# حد يعرف الاقي شغل وسكن جمب الجامعة ؟
# ----------
# Post ID: 100659372403370_265116596214653
# Message: 4731
# Male, Sophomore, Business:
#
# I need help
# I have a deep, secret love for a girl who goes to the same college as me. We've talked a few times, but I don't think she knows how I really feel about her. I want to tell her how much she means to me and how much I want to be with her, but I'm so afraid of being rejected.I don't know how to tell her, but I know I don't want to regret not taking the chance to be with the person who makes my heart race every time I see her.
# ----------
# Post ID: 100659372403370_265116576214655
# Message: 4730
# Male, Junior, Mechanical:
#
# بحبها جدا ولدرجة محدش يصدقها بس هي تجاربها السابقه كتيرة اوي وانا مكانش ليا تجارب كتيرة نهائي كانت كل شوية ترتبط بحد عادي فهل بحد دا عادي ولا ابعد عنها ردوا عليا بسرعه علشان كتير من اصدقائي بينبهوني أنها كدا مينفعش انصحوني علشان اورهقت
# ----------
# Post ID: 100659372403370_265116556214657
# Message: 4729
# Female, Sophomore:
#
# كان بدي غير العالم مش عارف كيف العالم غيرني
# ----------
# Post ID: 100659372403370_265116522881327
# Message: 4728
# Male, Freshman, Business:
#
# تباً للتعليم و الدراجات انا مالي و مال التعليم كان زماني قعد على الترعه بخد تان
# ----------
# Post ID: 100659372403370_265116336214679
# Message: 4727
# Male, Biotechnology:
#
# شوفت حد بيقول أنه ضهره واجعه وكده.....
# حابب بس اقول حاجه أن مهما كان ضهرك واجعك فهو اكيد مش واجعك اكتر من واحد فبايوتكنولوچي بيخش اللاب الساعه ٢ ونص يطلع منه الساعه ٨ ونص.... فضهره يفضل وجعه مثلا ٦ ايام ينام يصحا يلاقي نفسه في اللاب ده تاني..... ودوخينا يا دنيا
# ----------
# Post ID: 100659372403370_265116319548014
# Message: 4726
# Male:
#
# I want to play padel for the first time and I don’t have experience or padel buddie
# Any suggestions
# ----------
# Post ID: 100659372403370_265116282881351
# Message: 4725
# Male:
#
# Hey all, After 3 years in the fcn uni I discovered that I don’t have any friends as all of them are using me for there interests. I was stupid and I am sad on myself for letting them do that. Now I am very lonely and I don’t know what to do. Shame!
# ----------
# Post ID: 100659372403370_265116222881357
# Message: 4724
# Female, Graduate, Engineering:
#
# Ba7esak mesh aman ya aman
# ----------
# Post ID: 100659372403370_265115996214713
# Message: 4723
# Male, Freshman, Computer Science:
#
# طب ايه السنه خلصت واحنا قاعدين بنعمل eye contact مش ناويه تحسي علي دمك بقا و تعملي حاجه؟
# ----------
# Post ID: 100659372403370_260816083311371
# Message: 4722
# Female, Junior, Computer Science:
#
# و دلوقتي باقي كام ساعه علي اخر امتحان في سنه ٣ في جمله معلقه معايا بقالي حبه كل م  اقول خلاص لا انا مالي مش هساعد حد و خلاص باقي وقت قليل جدا اني اساعد اي حد او ابعت اي حاجه  في ناس اشطر مني بكتير ممكن تساعد و تفهم احسن  و اركز و اذاكر انا بقي بلقي ان في جمله وحده بس بتيجي في بالي (لن تنالو البر حتي تنفقوا من ما تحبون ) معرفش ايه علاقتها بالموضوع بصراحه بس بقول لا انا هبعت عشان ربنا يكرمني انا كمان و لما بحاول اكبر دماغي بحس بتأنيب ضمير اللي هو ليه ممكن مساعدش حد حتي لو الناس دي كنت مش برتاحلهم او معرفهمش اصلا  اكيد ربنا حطنا في طريق بعض عشان نساعد بعض و نعلم بعض بجد ربنا يكرمنا كلنا و يوفقنا و بجد فكره انك تساعد حد اي كان شكل المساعده  ف اكيد ربنا هيساعدك و يكرمك في حاجه تانيه♥️
# دعواتكم 🙏🏻
# ----------
# Post ID: 100659372403370_260816049978041
# Message: 4721
# Female, Sophomore, Computer Science:
#
# ياريت الولاد اللي بتشرب vape عند quick و خصوصا ابو شعر و دقن اللي في cs بلاش تنفخ الدخان في اللي قدامك احنا والله بنتعمي منه و انا مقدره ان ريحتها حلوه بس متقرفش اللي جابونا
# ----------
# Post ID: 100659372403370_260816016644711
# Message: 4720
# Male, Outcomer, Engineering:
#
# I am from outside the university and consideration to transfer, I needed to get to someone from industrial engineering, preferably senior
# ----------
# Post ID: 100659372403370_260815989978047
# Message: 4719
# Male, Biotechnology:
#
# رساله لدكتور البايوانفورمتكس وال NGS:
# دكتور S اللي من must انت فشختتتتتني عمال تقولي central dogma.... central dogma انا صدعت.
# ----------
# Post ID: 100659372403370_260815943311385
# Message: 4718
# Female, Outcomer:
#
# لو اتنين مرتبطين و خروجوا مع بعض قعدوا ف مكان شربوا حاجه هل طبيعي ان الولد ميعرضش يدفع و يخلى الحساب النص بالنص ف كل خروجه لاني خايفه اكون ظالماه و مش قادره احدد هو كده شخص بخيل ولا لا
# ----------
# Post ID: 100659372403370_260815683311411
# Message: 4717
# Male, Junior, Engineering:
#
# ازاي احافظ علي سلامتي النفسية خلال دراستي في الجامعة؟
# ----------
# Post ID: 100659372403370_260815643311415
# Message: 4716
# Prefer not to say:
#
# هيجرى ايه يا جماعة لو نعمل blind dates هتبقى جامدة أوي ممكن نعمل booth ناس تسجل اللي interested في الحوار ده و ن match كل اتنين مع بعض و يتكلموا و هما مش شايفين بعض لمدة ٥ دقائق كدا و يقرروا هما هينزلوا مع بعض date حقيقي و لا لأ ممكن ألاقي ناس مقبلة على ده؟
# ----------
# Post ID: 100659372403370_260815613311418
# Message: 4715
# Prefer not to say:
#
# المجاش انهارده الجامعه فايته كتير قوي
# ----------
# Post ID: 100659372403370_260815349978111
# Message: 4714
# Male, Senior, Engineering:
#
# من طلب العلا سهر الليالي
# و من سهر الليالي، has to be proud
# ----------
# Post ID: 100659372403370_260815283311451
# Message: 4713
# Faculty/Staff Member:
#
# قال النبي ﷺ: "إني لا أصافح النساء"
#
# قالت عائشة رضي الله عنها: "ما مست يد رسول الله صلى الله عليه وسلم يد امرأةٍ قط، ما كان يبايعهن إلا بالكلام"
#
# "لأن يطعن في رأس أحدكم بمخيط من حديد خير له من أن يمس امرأة لا تحل له"
# ----------
# Post ID: 100659372403370_260815003311479
# Message: 4712
# Male, Sophomore, Business:
#
# Do not leave your things alone again, as we used to, because nu is not safe at the moment
# ----------
# Post ID: 100659372403370_260814936644819
# Message: 4711
# Male:
#
# Fact:
#
# مفيش حد واخد التيرم التاني جد غير الدكاترة والمعيدين والمنايفة...
# ----------
# Post ID: 100659372403370_260814596644853
# Message: 4710
# Female:
#
# بما اننا داخلين علي فتره projects و presentations
# انا بتوتر جدا وانا بتكلم قدام حد و قبلها بيوم بكون خايفه جدا و بيجيلي panic ف ايه اقدر اعمله يقلل التوتر و الخوف والقلق علشان بجد تعبت
# شكرا مقدما
# ----------
# Post ID: 100659372403370_260814573311522
# Message: 4709
# Male:
#
# قلتلهم نلعب الغماز عشان تغمزلي و أغمزلها.. غمزت لي الكل و سابتني في الأخر أقول مين الغماز... وانا عشان مغفل قولت لايمكن تكون هيا و متغمزليش و شكت في واحد تاني. بس انا مش مضايق هي عشان أكيد مكسوفه مني أو بترازيني فا عشان كده مغمزتليش (أتمني يعني)
# ----------
# Post ID: 100659372403370_260814513311528
# Message: 4708
# Male, Junior, Computer Science:
#
# ليه منعملش event في الجامعة و يجيبوا حازم الصديق و احمد عامر بتوع وعي ؟؟؟؟؟؟
# ----------
# Post ID: 100659372403370_260814179978228
# Message: 4707
# Male, Freshman, Business:
#
# At first I thought having different schedule sucked but it made me realize how much I liked you and helped me with all of the mixed feelings I had for you
# ----------
# Post ID: 100659372403370_260814119978234
# Message: 4706
# Male:
#
# محدش يختار وجبة eftar SU اللى فيها صلصة عشان بشعة جدا 🤮🤮
# بس على الجانب الاخر البانية كان قشطة يتاكل
# ----------
# Post ID: 100659372403370_260814063311573
# Message: 4705
# Male:
#
# شاورما ابو حاتم اجمد شاورما في اكتوبر وزايد
# ----------
# Post ID: 100659372403370_260814033311576
# Message: 4704
# Prefer not to say:
#
# الجامعه زودتها اوووووي في موضوع القرارات القهريه دي ! مين المفروض يتكلم بالنيابه عننا ؟؟ اتحاد الطلبه سبوبه و دايره و مفيش في ايد الطالب الغلبان حاجه يا اما يبقي زي بتوع الاتحاد و المطبلتيه يا اما يقعد ساكت و يستقبل الخره
# ----------
# Post ID: 100659372403370_260813979978248
# Message: 4703
# Prefer not to say:
#
# بمناسبة دخول موسم الprojects
# ازاي نخرج من تييم شغل صحاب من غير ما حد يزعل لو مش مرتاحين في الشغل معاهم
# ----------
# Post ID: 100659372403370_260813543311625
# Message: 4702
# Female:
#
# Had y3rf therapist hlw f October aw zayed w mykonsh mn abo almara b 800 dol
# ----------
# Post ID: 100659372403370_260813066645006
# Message: 4701
# Female:
#
# معلومه للبنات اللي بتصلي فالمسجد:
# مينفعش يبقي فيه جماعتين في مسجد واحد لأني شوفت النهارده بنات دخلو صلو جماعه وانا كنت بصلي مع صحابي جماعه فالصح يإما تخشو تصلو مع الجماعه اللي بتصلي ياما تستنو يخصلو وتصلو بعدهم او كل واحده تصلي لوحدها لأني مفيش إمامين لمسجد واحد فالبالتالي لا يوجد جماعتين في مسجد واحد.♥️
# ----------
# Post ID: 100659372403370_260813029978343
# Message: 4700
# Male, Freshman, Business:
#
# That moment when you realize that both of you liked each other but both of you didn't know and didn't know how to start talking to each other
# ----------
# Post ID: 100659372403370_260812973311682
# Message: 4699
# Prefer not to say:
#
# حبيت اخلي الناس تاخد بالها ان الراجل بتاع الحسبات مش ديما بيقول المصاريف صح
# كل مرة اروح اسأل المفروض ادفع كام بيكون فيه من 500 ل 900 جنيه زيادة
# و لما ارجع اتأكد من الحساب و اقله اني دفعت مبلغ معين الترم الي فات بيروح شايل الزيادة ( الموقف حصل كذا مرة)
# مش عارف هو بيزود من عنده و بيشوف الناس هتاخد بالها ولا لا
# انا عارف ان الزيادة عبيطة بس الموضوع استفزني بالذات لو حصل مع كذا حد هيكون المبلغ كبير
# ----------
# Post ID: 100659372403370_260812896645023
# Message: 4698
# Sophomore:
#
# العيال الي كانوا قاعدين مشغلين اغاني بصوت عالي في نهار رمضان حقيقي انتو في قمه قله الذوق وعدم الاحترام
# ----------
# Post ID: 100659372403370_260812653311714
# Message: 4697
# Male, Business:
#
# Kan nfsy a2wlk men awl nzra bas 2olt a5od wa2ty El term 5ls w gadwalna 2tgyrt
# ----------
# Post ID: 100659372403370_260812623311717
# Message: 4696
# Female, Biotechnology:
#
# اي يجمااعة هو احنا مالناش يوم فطار ولا اي ؟
# ----------
# Post ID: 100659372403370_260812593311720
# Message: 4695
# Male, Senior, Mechanical:
#
# هو مين سينت ال su
# ----------
# Post ID: 100659372403370_260812559978390
# Message: 4694
# Prefer not to say:
#
# -ﻗﺎﻝ ﻟﻬﺎ ﺍﺗﺮﻳﻦ ﺍﻟﻘﻤﺮ ؟
# -ﻗﺎﻟﺖ ﻟﻪ .. ﻧﻌﻢ ﻓﻬﻮ ﻫﻨﺂﺁﺁﻙ .. ﺃﺗﺮﺍﻩ ؟
# -ﻗﺎﻝ ﻟﻬﺎ .. ﺃﻳﻦ ﻫﻮ ..؟
# -ﻗﺎﻟﺖ ﻟﻪ .. ﺃﻧﻈﺮ ﺍﻟﻰ ﺍﻟﺴﻤﺂﺀ ﻟﺘﺮﺍﻩ !!!..ﺍ
# -ﻗﺎﻝ ﻟﻬﺎ .. ﻟﻤﺎ ﺃﺗﻌـﺐ ﻧﻔﺴﻲ ﺑﺎﻟﺒﺤﺚ ﻋﻨﻪ ﻭﻫﻮ ﺑﺠﺂﻧﺒﻲ
#
# ﻓﻘـﺎﻟﺖ ﻟﻪ :
# -ﺍﻧﺖ ﺣﻤﺎﺭ ﻫﻮ ﻓﻲ ﻗﻤﺮ ﻋﻠﻰ ﺍﻷﺭﺽ
#
# ﻓﻘﺎﻝ ﻟﻬﺎ :
# -ﺍﻟﺤﻖ ﻣش ﻋﻠﻴﻜﻲ
# -ﺍﻟﺤﻖ ﻋﻠﻲ اللي عايز ﻳﺨﻠﻴﻜﻲ ﻗﻤﺮ
# ﻭﺍﻧﺘﻲ ﺷﺒﻪ ﺳﻨﺪﻭيتش الجبنة ...
# ههههههههههههه
# ----------
# Post ID: 100659372403370_260812246645088
# Message: 4693
# Female, Senior:
#
# مساء الخير يا جماعه
# ان شاء الله اسبوع الميد ترم يعدي علي خير للكل و كل سنه و انتم طيبين
#
# انا كنت عايزه بس اقول للناس اللي هتتخرج السنه دي اني بعمل customised caps للتجرج و كنت عملت لبنوته السنه اللي فاتت و هعمل ليا و لصحابي السنه دي ف لو حد عنده ديزاين او حاجه معينه عايز ينفذها انا ممكن اعملها و ان شاء الله نتخرج علي خير و نفرح كلنا 🎓🎓
#
# دي صور الكاب اللي انا عملتها
#
# اللي عايزه/عايز يكتب كومنت و نتفق علي التفاصيل
#
# يلا خلينا نفرح شويه بدل الضغط اللي احنا فيه 😅😂
# ----------
# Post ID: 100659372403370_260812196645093
# Message: 4692
# Female, Freshman:
#
# شلة الكويكيين اتحجزوا كلهم تقريبا🤧😭
# ----------
# Post ID: 100659372403370_260812163311763
# Message: 4691
# Prefer not to say:
#
# رساله من موقعي هذا للبيج رامي بتاع ال Bioinformatics وال NGS..... انت فاشختنا
# ----------
# Post ID: 100659372403370_260811953311784
# Message: 4690
# Male, Freshman, Biotechnology:
#
# يجماعه محتاجين حفله تانيه بعد رمضان ضروري
# ----------
# Post ID: 100659372403370_260811883311791
# Message: 4689
# Male, Senior, Finance:
#
# WTF happened to this page? Did the admin die or did every single MFer lose hope in the NU all at the same time?
# ----------
# Post ID: 100659372403370_260811826645130
# Message: 4688
# Male, Junior:
#
# بعد اما شوفت نص بنات الجامعة الوحش بقيت خايف جدا من خطوة الخطوبة بقيت حاسس ان مفيش واحدة مضمونة واكيد انا كا شب مكلمش بنت قبل كدة وملهوش في اللف والدوران هيبقي محتاج واحدة زيه مكلمتش حد قبل كدة وملهاش في اللف والدوران مش عارف انا اللي شايف غلط وشايف الموضوع كبير وان مفيش خيانة لثقة اهل وقلة رجولة في البيت ولا فيه وانا صح وهما غلط مبقتش عارف ايه الصح وايه الغلط
# ----------
# Post ID: 100659372403370_260811596645153
# Message: 4687
# Prefer not to say:
#
# هو الادمن وخد اجازه ولايه انا عايز درما و اكشن
# ----------
# Post ID: 100659372403370_260811556645157
# Message: 4686
# Female:
#
# انت يعمممم الادمن رجع شغفك مش لاقية حاجة تسلينى بعد انطفاء البيدج
# ----------
# Post ID: 100659372403370_260811533311826
# Message: 4685
# Sophomore, Business:
#
# Howa youm el khamis ely gay 20/4 haykoon agaza?
# ----------
# Post ID: 100659372403370_260839983308981
# Message: forms.gle/4yJdWMBgdMSWjsTt5
# ----------
# Post ID: 100659372403370_260811503311829
# Message: 4684
# Junior:
#
# انا مخنوقه اووي اووووي درجات الترم ده كلها وحشه و مش عارفه  اقول  اللي ف البيت ازاي
# ----------

# %% [markdown]
# ### Get likes on post

# %%
post_id = "100659372403370_350757634317215"

url = f"https://graph.facebook.com/v19.0/{post_id}/likes?summary=true&access_token={access_token}"

response = requests.get(url)
data = response.json()

# Extract the number of likes
likes_count = data.get("summary", {}).get("total_count", 0)

print(f"The post has {likes_count} likes.")
# Out:
# The post has 4 likes.

# %% [markdown]
# ### Get comments

# %%
post_id = "100659372403370_422582210468090"


all_comments = []

# Facebook Graph API endpoint URL
url = f"https://graph.facebook.com/v19.0/{post_id}/comments?access_token={access_token}&limit=100"

while True:
    response = requests.get(url)
    data = response.json()
    
    # Check if there are more comments
    if 'data' in data:
        all_comments.extend(data['data'])
    
    # Check if there are more pages of comments
    if 'paging' in data and 'next' in data['paging']:
        url = data['paging']['next']
    else:
        break

# Print the comment details
for comment in all_comments:
    print(f"Comment ID: {comment['id']}")
    print(f"Comment Message: {comment.get('message', 'N/A')}")
    print("----------")
# Out:
# Comment ID: 422582210468090_813868573931617
# Comment Message: لما اليأس من الحياه
# ----------

# %%
scope = ["https://spreadsheets.google.com/feeds",'https://www.googleapis.com/auth/spreadsheets',"https://www.googleapis.com/auth/drive.file","https://www.googleapis.com/auth/drive"]
creds = ServiceAccountCredentials.from_json_keyfile_name("creds.json", scope)
client = gspread.authorize(creds)
sheet = client.open("NU Confessions (Responses)").sheet1  # Open the spreadhseet
sheet2 = client.open("NU Confessions (Responses)").worksheet("Sheet2")

confNum = int(sheet2.acell("A1").value)
startPoint = int(sheet2.acell("B1").value)
print("Number of new confessions: "+str(len(sheet.get_all_values()) - startPoint+1))
# Out:
# Number of new confessions: 32

# %%
len(sheet.get_all_values())
# Out:
# 6000

# %%
startPoint
# Out:
# 4969

# %%
confNum
# Out:
# 4782

# %%
#Schedule times
#timeList = ["12:30am", "1:00am", "1:30am", "2:00am", "7:00pm", "7:30pm", "8:00pm", "8:30pm", "9:00pm", "9:30pm", "10:00pm", "10:30pm", "11:00pm", "11:30pm", "11:59pm"]
timeList=[]
for i in range(1, 100):
    value = sheet2.acell("D"+str(i)).value
    if(value == None):
        break
    else:
        timeList.append(value)

try:
    postTime = sheet2.acell("C1").value
    timeIndex = timeList.index(postTime.split(" ")[1].lower()) #Get index of current time to post
except:
    print("Error within last scheduled time in sheet2!")
    startPoint = 9999999

print(postTime)
day = int(postTime.split(" ")[0].split("-")[0])
month = int(postTime.split(" ")[0].split("-")[1])
year = int(postTime.split(" ")[0].split("-")[2])

endPoint = int(input("Enter end point in sheet - 0 to post all: "))
if endPoint == 0:
    endPoint = len(sheet.get_all_values())

print()
# Out:
# 21-7-2023 1:00pm

# %%
c=1
for i in range(startPoint, endPoint + 1):
    #delay for Gspread api write request quota
    if(c%5==0):
        time.sleep(30)

    row = sheet.row_values(i)

    #Reverse arabic confession
    if not (row[0][0].isdigit()):
        row.reverse()

    confession = "#" + str(confNum) + "\n"
    for j in range(2, len(row)):
        if j == len(row)-1:
            confession = confession + row[j] + ": \n\n"
        else:
            if (row[j] == None) or (row[j] == "") or (row[j] == "Prefer not to say"):
                continue
            confession = confession + row[j] + ", "
    confession = confession + row[1]
    confession = confession.replace("#", "") #remove all hash symbols form string
    print(confession)
    print()

    isSkipped = sheet.acell("H"+str(i)).value
    if isSkipped=="1":
        sheet.format("B"+str(i), {"backgroundColor": {"red": 1.0, "green": 0.0, "blue": 0.0}})
        print("Skipped")
    else:
        timeIndex += 1
        if(timeIndex >= len(timeList)):
            print("Schedule time overflow!")
            date = datetime.datetime(year, month, day)
            date += datetime.timedelta(days=1)
            day = date.day
            month = date.month
            year = date.year
            timeIndex = 0

        postTime = timeList[timeIndex].split(":")
        print("post time ", postTime)
        hour = int(postTime[0])
        minute = int(postTime[1][:-2])
        if ((postTime[1][-2] + postTime[1][-1]).lower() == "pm"):
            hour += 12
        date = datetime.datetime(year, month, day, hour, minute)
        epochTime = date.timestamp()
        print("date ",date)

        sheet.update("G" + str(i), [[str(confNum)]])
        confNum += 1

        sheet2.update("C1", [[str(day) + "-" + str(month) + "-" + str(year) + " " + postTime[0] + ":" + postTime[1]]])
        sheet.update("F"+str(i), [[str(day)+"-"+str(month)+"-"+str(year)+" "+postTime[0]+":"+postTime[1]]])
        sheet.format("B" + str(i), {"backgroundColor": {"red": 0.0, "green": 1.0, "blue": 0.0}})
        print("Posted successfully!")

    sheet2.update("A1", [[str(confNum)]])
    sheet2.update("B1", [[str(i+1)]])
    c=c+1

    print("--------------------------------------------------\n")
# Out:
# 4783
# Female, Sophomore, AI:
#
# حد يعرف دار ايتام اقدر اتطوع فيها ؟
#
# post time  ['4', '00pm']
# date  2023-07-21 16:00:00
# C:\Users\eslam\AppData\Local\Temp\ipykernel_13552\1695173221.py:51: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   sheet.update("G" + str(i), [[str(confNum)]])
# C:\Users\eslam\AppData\Local\Temp\ipykernel_13552\1695173221.py:54: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   sheet2.update("C1", [[str(day) + "-" + str(month) + "-" + str(year) + " " + postTime[0] + ":" + postTime[1]]])
# C:\Users\eslam\AppData\Local\Temp\ipykernel_13552\1695173221.py:55: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   sheet.update("F"+str(i), [[str(day)+"-"+str(month)+"-"+str(year)+" "+postTime[0]+":"+postTime[1]]])
# Posted successfully!
# C:\Users\eslam\AppData\Local\Temp\ipykernel_13552\1695173221.py:59: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   sheet2.update("A1", [[str(confNum)]])
# C:\Users\eslam\AppData\Local\Temp\ipykernel_13552\1695173221.py:60: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   sheet2.update("B1", [[str(i+1)]])
# --------------------------------------------------
#
# 4784
# 1:
#
# Bto3 el 2amn bgad b2o haga s3ben w b2o yab7l2o fena w yr5mo 3l tal3 w el da5l bgd b2a modo3 mo2rf
#
# Skipped
# --------------------------------------------------
#
# 4784
# Male, 1:
#
# How can I take the first step? My first love😓
#
# Skipped
# --------------------------------------------------
#
# 4784
# Male, Junior, 1:
#
# bmonasbet video el elections, just wanted to say that the bylaws used to say that the union is "an independent free union that is not governed or controlled by Nile
# University’s Administration, Staff, Faculty or Board of Trustees." Meanwhile it's the student life office who interviewed & chosen those people. nice joke
#
# Skipped
# --------------------------------------------------
#
# 4784
# Female, Senior, Biotechnology:
#
# حياتي بتخلص والديدلاينز مش هتخلص
#
# post time  ['5', '00pm']
# date  2023-07-21 17:00:00
# Posted successfully!
# --------------------------------------------------
#
# 4785
# Sophomore, AI, 1:
#
# Gma3a amlo el form please m7tagen daragt help………….
# https://docs.google.com/forms/d/e/1FAIpQLSeDJUNQR2wUWQ_MYJOnWuXfDVBqQ-dukaE8Ksx1n_5AmBdP0w/viewform?usp=sf_link
#
# Skipped
# --------------------------------------------------
#
# 4785
# Male, Junior, 1:
#
# 3amel feha sharef f45 wbtrod wenta 5areg mn el et7ad 34an tb2a elections committee wtdeha le so7abk ely nazlen brdo, danto beg7en le drgt ano el wad ely kan representative m3 Amer nzel m3ako fl elections committee 3ady
# Same for aly ely mun so7abo nazlen presedent w vice. You all punch of scammers
#
# Skipped
# --------------------------------------------------
#
# 4785
# Male:
#
# ١-خد يسطا جرب نفس مش هتخسر حاجة
# أكيد ؟
# -يعم عيب عليك جرب مرة مش هتعمل حاجة
# يسطا إلحقني
# -ايه يا قلب أخوك
# بقيت بشرب علبتين في اليوم
# -يعم وماله انت كده بتروق على حالك
# خالصة يخويا
#
# ٢- بس كده بعدت عن أبويا وأمي ووصلت الجامعة أطلعلي سجارتين هكسر الثقة اللي هما واخدينها فيا اني شخص كويس في داهية خليهم مغفلين هرجع البيت بوقي مفهوش ريحة ومخبي سجايري في الشنطة وبس كده يمعلم ضحكت عليهم (ربنا شايفك كده كده)
#
# ٣- أنا واد سرسج وعايز ابقى مع الشلة الخطر دي ❌
# هبدأ أدخن عشان أبقى راجل يتعملي حساب اه اومال ابقى راجل ازاي!! منا مقطع بطايقي ومفيش مني اتنين
#
# ٤-ايه يا برو انت مبتشربش الڤيب ليه احنا جيل جديد لازم تمشي مع الترند والتقدم وتبقى روش طحن
#
# ٥-يبنتي أنا حرة بعيش حياتي أنا وكام بت بنشيش مع بعض اه هما معايا شجعوني أنا اتكسف ابقى بنوتة كيوتة بشرب لوحدي أما أنا شايفة ناس زيي
#
# ٦- ايه ده في ناس كتير بتتكلم على اننا نبطل الزفت ده .. جامد طرش .. كده العين علينا والناس بتتكلم عننا مش هنحقق اللي هما عايزنه خليهم يتحايلوا علينا .. احنا المشطشطين 🌶️🌶️
#
# يا حبيب قلب أخووووك اسمعناااي نصيحة من شاب زيك انت بتهلك صحتك ليه ؟ مفيش حد عاقل بيدخل دخان جوه جسمه يجيب أجل الرئة
# إلحق نفسك واستعين بالله وبطل السجاير ومشتقاتها
# ايه علاقة الرجولة بإنك تشرب ؟ ايه علاقة انك خلاص بقيت كبير بإنك تشرب؟  اتقي الله .. ابعد عن صحاب السوء بدل ما تلاقي نفسك بتتجر حبة حبة لحاجات ألعن من السجاير ..
# وفي الآخر: التدخين سكة ضلمة أخرها حيطة سد
#
# ربنا يهدينا كلنا إلى الطريق الصحيح يا أخواتي ❤️
#
# post time  ['6', '00pm']
# date  2023-07-21 18:00:00
# Posted successfully!
# --------------------------------------------------
#
# 4786
# Male, Junior, Computer Science, 1:
#
# البنت الكانت بتصور قدام الريسبشن في الدور التاني ولما بصتلها ضحكت انتي قمر اوي ❤️
#
# Skipped
# --------------------------------------------------
#
# 4786
# Junior, BMD, 1:
#
# روحتوا فين
#
# Skipped
# --------------------------------------------------
#
# 4786
# Male, Graduate, 1:
#
# بما إني شايف ناس كثير بتنزل تطلب من الناس يملو الفورم علشان كورس الإنجليش والاليكتيفز وكده، انا أول مره عملت زيكم كده ولقيت قليلين إللي ملو الفورم ، من ساعتها وكل مرة بملى انا الفورم كذه مرة ب responses مختلفة ، وبتطلع روح الشيزوفرينيا اللي جوايا وبجادل نفسي في الرأي في كل مرة بملى فيها الفورم،، وكنت بجيب A في آخر الكورس والدنيا جميلة لما تفقدو الامل في انكم تلمو responses كفاية اتعبو شوية وصحو المؤلف اللي جواكم وريحوا دماغكم من اللف ورا الناس وهتتعودو كده كده ع الحركة دي زي ما انا اتعودت، مشو الدنيا علشان تتخرجو وربنا يوفق الجميع 😂
#
# Skipped
# --------------------------------------------------
#
# 4786
# Male, Junior, AI:
#
# جماعه حد عارف هنا بشتغل في الجامعه سنجل و نظامها ايه عشان الواحد هيموت علي نفسه عشان مفيش كده ارجو الرد سريعا مريعا عشان نقول مبروك
#
# post time  ['7', '00pm']
# date  2023-07-21 19:00:00
# Posted successfully!
# --------------------------------------------------
#
# 4787
# Male, Junior:
#
# حزين لدرجة أني مش حاسس برغبة في أني أعيش على الرغم أني مش حاسس في رغبة أني أموت
#
# post time  ['8', '00pm']
# date  2023-07-21 20:00:00
# Posted successfully!
# --------------------------------------------------
#
# 4788
# Female, Senior, Biotechnology:
#
# 7aba a2ol l doctor el molecular bta3et el lab en bgd rabna ysam7ha wrbna m4 hybarek laha f 7yatha abdn
#
# post time  ['9', '00pm']
# date  2023-07-21 21:00:00
# Posted successfully!
# --------------------------------------------------
#
# 4789
# Male, Sophomore:
#
# انا حيحانه و مش عارفه اعمل ايه
#
# post time  ['10', '00pm']
# date  2023-07-21 22:00:00
# Posted successfully!
# --------------------------------------------------
#
# 4790
# Female, Senior, 1:
#
# يبنى انطق بقا يخربيتك
#
# Skipped
# --------------------------------------------------
#
# 4790
# Senior, Biotechnology:
#
# To biotechnology staff: وَاتَّقُوا يَوْمًا تُرْجَعُونَ فِيهِ إِلَى اللَّهِ
# القانون بيطبق ع gpa 4 نفس القانون بيطبق ع gpa 0.2 ده يمكن gpa 4 ده يستاهل الفصل من الجامعة مش شيل مادة وبالقانون
#
# post time  ['11', '00pm']
# date  2023-07-21 23:00:00
# Posted successfully!
# --------------------------------------------------
#
# 4791
# Female, Senior:
#
# 7/2/2024
# Im so proud man , wish you all happiness in the world☁️
#
# post time  ['11', '59pm']
# date  2023-07-21 23:59:00
# Posted successfully!
# --------------------------------------------------
#
# 4792
# Male, Freshman, BMD, 1:
#
# 🏳️‍🌈 You can't stop the love love
# You can't tell us NO NO
# We can't get enough
# Everybody needs a man
# You can't take our freedom
# Couples or a threesome
# We are what we become
# Everybody needs a man
# Oh oh oh
# Everybody needs a man
# Oh oh oh
# Everybody needs a man 🏳️‍🌈
#
# Skipped
# --------------------------------------------------
#
# 4792
# Male, Graduate, Finance, 1:
#
# هو الأدمن الغلبان عنده السكر او حاجة؟ اصل كل شوية يدخل فى غيبوبة و يقعد كام شهر من غير ما ينزل الconfessions .الف سلامة على احلى ادمن فى الدنيا
#
# Skipped
# --------------------------------------------------
#
# 4792
# Sophomore, Business, 1:
#
# A7a el admin Lesa 3aysh
#
# Skipped
# --------------------------------------------------
#
# 4792
# Outcomer, Computer Science, 1:
#
# ازاي اتعلم انجليزي كويس واعرف اتكلم
#
# Skipped
# --------------------------------------------------
#
# 4792
# Male, Graduate, Mechanical:
#
# متتخرجوش
# لو بتحرق نفسك على شهادتك مش دي اللي هتشغلك الا لو معيد او حاجة في R&D، غير كده هو التدريبات و الextra curricular activities و الكلام اللي اغلبكم بيشوفوه مضيعة للوقت
# تاني متتخرجوش
# برضه عشان مافهمش غلط، اتعب و افشخ نفسك كدة كدة بس ماخليش تعبك في حاجة واحدة و تقفل على تفسك الباب لحاجات احسن يعني
# لو ميكاترونكس و مش هتسافر برة مصر فا حول اندستريال اسهل
# باي
#
# Schedule time overflow!
# post time  ['1', '00am']
# date  2023-07-22 01:00:00
# Posted successfully!
# --------------------------------------------------
#
# 4793
# Male, Sophomore, Computer Science:
#
# انا جعان
#
# post time  ['2', '00am']
# date  2023-07-22 02:00:00
# Posted successfully!
# --------------------------------------------------
#
# 4794
# Female, Sophomore, Biotechnology:
#
# mashe
#
# post time  ['1', '00pm']
# date  2023-07-22 13:00:00
# Posted successfully!
# --------------------------------------------------
#
# 4795
# Female, Sophomore, Biotechnology:
#
# مش مستعده للي بعد العيد
#
# post time  ['2', '00pm']
# date  2023-07-22 14:00:00
# Posted successfully!
# --------------------------------------------------
#
# 4796
# Female, Sophomore:
#
# ببني انت نظراتك كلها اعجاب وحب بس انت مصاحب فووق😂
#
# post time  ['3', '00pm']
# date  2023-07-22 15:00:00
# Posted successfully!
# --------------------------------------------------
#
# 4797
# Male, Senior, Computer Science:
#
# معيدين cs الجدد مرضى نفسين و عندهم نقص بطريقه غريبه بطلوا عقد بقا
#
# post time  ['4', '00pm']
# date  2023-07-22 16:00:00
# Posted successfully!
# --------------------------------------------------
#
# 4798
# Male, 1:
#
# I'm gay
#
# Skipped
# --------------------------------------------------
#
# 4798
# Male:
#
# الحزن
#
# post time  ['5', '00pm']
# date  2023-07-22 17:00:00
# Posted successfully!
# --------------------------------------------------
#
# 4799
# Female, Senior, Computer Science:
#
#  حوارات ال nu community  رجعت تانييي💃🏻💃🏻
#
# post time  ['6', '00pm']
# date  2023-07-22 18:00:00
# Posted successfully!
# --------------------------------------------------
#
# 4800
# Male, Graduate:
#
# وحشتني ايام الجامعه ومكنتش متخيل هقول كدا، زي ما وحشتني ايام الجيش ومكنتش متخيل هقول كدا
# مسم
#
# post time  ['7', '00pm']
# date  2023-07-22 19:00:00
# Posted successfully!
# --------------------------------------------------

# %%
f = open("Facebook token.txt", "r+")
fbPageid = f.readline().strip("\n")
fbToken = f.readline().strip("\n")
f.close()

# %%
response = requests.post("https://graph.facebook.com/" + fbPageid + "/feed" +
                            "?published=false" +
                            "&message=" + "hello" +
                            "&access_token=" + fbToken)

# %%
response.json()
# Out:
# {'error': {'message': 'Error validating access token: Session has expired on Saturday, 13-Apr-24 14:00:00 PDT. The current time is Saturday, 13-Apr-24 16:41:04 PDT.',
#   'type': 'OAuthException',
#   'code': 190,
#   'error_subcode': 463,
#   'fbtrace_id': 'AgZcCHrUsq9gxIqwoZJpSF5'}}
